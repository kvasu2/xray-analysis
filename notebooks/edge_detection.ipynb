# %%
import os
import sys
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
import cv2

parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# %%
parent_dir
# Out:
# 'c:\\Users\\venka\\Desktop\\xray-analysis'

# %%
image_dir = os.path.join(parent_dir, 'archive', 'images_001', 'images')

# %%
image_dir
# Out:
# 'c:\\Users\\venka\\Desktop\\xray-analysis\\archive\\images_001\\images'

# %%
import os
from PIL import Image

image_files = os.listdir(image_dir)
images = []

for file in image_files:
    image_path = os.path.join(image_dir, file)
    break
    
    
    
    

# Now you can work with the images
# For example, you can display the first image

# %%
# Read the original image
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE) 
# Display original image
output_path = os.path.join(parent_dir,'original_image.jpg')
plt.imshow(img, cmap='gray')

# %%
img_blur = cv2.GaussianBlur(img, (3,3), 0) 
plt.imshow(img_blur,cmap="gray")

# %%
# Sobel Edge Detection
sobelx = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
sobely = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
sobelxy = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
# Display Sobel Edge Detection Images
sobelx_path = os.path.join(parent_dir,'sobelx.jpg')

sobely_path = os.path.join(parent_dir,'sobely.jpg')

sobelxy_path = os.path.join(parent_dir,'sobelxy.jpg')


 
# Canny Edge Detection
edges = cv2.Canny(image=img_blur, threshold1=25, threshold2=30) # Canny Edge Detection
# Display Canny Edge Detection Image

# %%
plt.imshow(edges, cmap='gray')

# %%
plt.imshow(sobelx,cmap="gray")

# %%
plt.imshow(sobely, cmap='gray')

# %%
plt.imshow(sobelxy, cmap='gray')

# %%
plt.imshow(edges, cmap='gray')
